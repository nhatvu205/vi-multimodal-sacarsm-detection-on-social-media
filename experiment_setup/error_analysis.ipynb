# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/DO_AN_KI_2_NAM_3/IE403/[2] Đồ án"
# Out:
# /content/drive/.shortcut-targets-by-id/12ue3-RNz1XOZO3Dk6tkUt9Ek7rteBaxD/DO_AN_KI_2_NAM_3/IE403/[2] Đồ án

# %%
# !python error_analysis.py prediction_test test.json
# Out:
# Loading ground truth: /content/drive/MyDrive/DO_AN_KI_2_NAM_3/IE403/[2] Đồ án/test.json
#   → 736 samples
#
# === FILE SCAN (debug) ===
#   phobert_base: ['predictions_test_s1.jsonl', 'predictions_test_s2.jsonl', 'predictions_test_s3.jsonl', 'predictions_test_s4.jsonl']
#   mbert: ['predictions_test_s1.jsonl', 'predictions_test_s2.jsonl', 'predictions_test_s3.jsonl', 'predictions_test_s4.jsonl']
#   roberta_base: ['predictions_test_s1.jsonl', 'predictions_test_s2.jsonl', 'predictions_test_s3.jsonl', 'predictions_test_s4.jsonl']
#   clip_vitl14: ['predictions_test_s1.jsonl']
#   vit_b32: ['predictions_test_s1.jsonl']
#   qwen: ['s1_pred.jsonl', 's2_pred.jsonl', 's3_pred.jsonl', 's4_pred.jsonl']
#   llava: ['s4_pred.jsonl', 's2_pred.jsonl', 's1_pred.jsonl', 's3_pred.jsonl']
#   cirm: ['predictions_test_s1.jsonl', 'predictions_test_s2.jsonl', 'predictions_test_s3.jsonl', 'predictions_test_s4.jsonl']
# ...

# %%
# !python extended_analysis.py test.json
# Out:
# ...
# EXTENDED ERROR ANALYSIS
# ...
#
# ⚠️  Label Conflict Samples: 345 / 736
#   → Saved: error_analysis_output/label_conflicts.jsonl
#
# ...
# SCENARIO: s1
# ...
#
# 📊 FP/FN Breakdown — Scenario s1
# Model                 Group         Total Err     FP     FN     FP%
# -----------------------------------------------------------------
# phobert_base          text                359    304     55   84.7%
# mbert                 text                354    292     62   82.5%
# roberta_base          text                339    266     73   78.5%
# clip_vitl14           image               234    206     28   88.0%
# vit_b32               image               371    352     19   94.9%
# qwen                  multimodal          314    204    110   65.0%
# llava                 multimodal          321      0    321    0.0%
# cirm                  multimodal          271    151    120   55.7%
# dt4mid                multimodal          226    106    120   46.9%
#
# 🌐 Error by Source — Scenario s1
# ...
