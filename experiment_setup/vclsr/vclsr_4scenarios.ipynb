# %%
# !rm -rf repo 2>/dev/null || true
# !git clone -b modelling-new --single-branch --depth 1 https://github.com/nhatvu205/vi-multimodal-sacarsm-detection-on-social-media.git repo

# %%
# !cd repo && pip install -r requirements.txt -q
# !cd repo && ls -la

# %%
# !cd repo && python -m experiment_setup.main \
  --config experiment_setup/configs/models/viclsr.yaml \
  --stage preprocess

# %% [markdown]
# ## s1

# %%
with open('/kaggle/working/repo/experiment_setup/configs/models/viclsr_s1.yaml', 'w') as f:
    f.write('''extends: viclsr.yaml

run:
  scenarios: [s1]
''')
print("s1 config created")

# %%
# !cd /kaggle/working/repo && python -m experiment_setup.main \
  --config experiment_setup/configs/models/viclsr_s1.yaml \
  --stage run

# %% [markdown]
# # s2

# %%
with open('/kaggle/working/repo/experiment_setup/configs/models/viclsr_s2.yaml', 'w') as f:
    f.write('''extends: viclsr.yaml

run:
  scenarios: [s2]
''')
print("s2 config created")

# %%
# !cd /kaggle/working/repo && python -m experiment_setup.main \
  --config experiment_setup/configs/models/viclsr_s2.yaml \
  --stage run

# %% [markdown]
# # s3

# %%
with open('/kaggle/working/repo/experiment_setup/configs/models/viclsr_s3.yaml', 'w') as f:
    f.write('''extends: viclsr.yaml

run:
  scenarios: [s3]
''')
print("s3 config created")

# %%
# !cat /kaggle/working/repo/experiment_setup/configs/models/viclsr_s3.yaml

# %%
# !cd /kaggle/working/repo && python -m experiment_setup.main \
  --config experiment_setup/configs/models/viclsr_s3.yaml \
  --stage run

# %% [markdown]
# # s4

# %%
with open('/kaggle/working/repo/experiment_setup/configs/models/viclsr_s4.yaml', 'w') as f:
    f.write('''extends: viclsr.yaml

run:
  scenarios: [s4]
''')
print("s4 config created")

# %%
# !cd /kaggle/working/repo && python -m experiment_setup.main \
  --config experiment_setup/configs/models/viclsr_s4.yaml \
  --stage run
